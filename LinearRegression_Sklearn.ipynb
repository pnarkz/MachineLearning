# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# 1) Veri yükleme
data = pd.read_csv('C:\\Users\\ASUS\\Downloads\\rounded_hours_student_scores.csv')
X = data[['Hours']].values    # (61,1)
Y = data['Scores'].values     # (61,)

# 2) scikit-learn ile Linear Regression
model = LinearRegression()
model.fit(X, Y)

# 3) Tahmin ve metrikler
Y_pred = model.predict(X)
m = model.coef_[0]
c = model.intercept_
mse = mean_squared_error(Y, Y_pred)

print(f"[sklearn] Eğim (m): {m:.4f}")
print(f"[sklearn] Kesim (c): {c:.4f}")
print(f"[sklearn] MSE: {mse:.3f}")

# 4) Grafikte gösterim
plt.scatter(X, Y, label='Gerçek Veriler', edgecolor='k')
plt.plot(X, Y_pred, color='green', label='Sklearn Regression')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.title('Student Scores – scikit-learn LinearRegression')
plt.legend()
plt.show()
mse_skl= mse
# Out:
# [sklearn] Eğim (m): 1.8942
# [sklearn] Kesim (c): 36.6781
# [sklearn] MSE: 11.583
